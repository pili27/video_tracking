# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import pandas as pd
import os
import io
import tensorflow as tf
from TP1_data.KalmanFilter import KalmanFilter
from scipy.optimize import linear_sum_assignment
#from KalmanFilter import KalmanFilter

# %%
# load detection
path = 'Filemail.com files 14.12.2023 fbhubejonusmcri/ADL-Rundle-6/det/det.txt'

# data
data = open(path, 'r').read()

# Column names as specified
column_names = ["frame", "id", "bb_left", "bb_top", "bb_width", "bb_height", "conf", "x", "y", "z"]

# Creating a DataFrame from the data
df = pd.read_csv(io.StringIO(data), names=column_names, header=None)
df.head(12)  # Displaying the first few rows of the DataFrame
# Out:
#     frame  id  bb_left  bb_top  bb_width  bb_height     conf  x  y  z
# 0       1  -1     1689     385   146.620    332.710  67.5670 -1 -1 -1
# 1       1  -1     1303     503    61.514    139.590  29.4390 -1 -1 -1
# 2       1  -1     1258     569    40.123     91.049  19.6010 -1 -1 -1
# 3       1  -1       31     525   113.370    257.270  17.0130 -1 -1 -1
# 4       1  -1     1800     483    94.660    214.810  11.9490 -1 -1 -1
# 5       2  -1     1689     385   146.620    332.710  66.7250 -1 -1 -1
# 6       2  -1     1312     503    61.514    139.590  36.6140 -1 -1 -1
# 7       2  -1     1744     476   123.420    280.060  16.9760 -1 -1 -1
# 8       2  -1     1254     537    52.000    118.000  15.9790 -1 -1 -1
# 9       2  -1       55     542    94.660    214.810   9.3326 -1 -1 -1
# 10      2  -1     1641     494    40.123     91.049   6.0638 -1 -1 -1
# 11      3  -1     1742     513    94.660    214.810  64.8030 -1 -1 -1

# %%
# example init kalman filter
def create_kalman():
    dt = 0.1
    u_x = 0
    u_y = 0
    std_acc = 1
    x_sdt_meas = 0.1
    y_sdt_meas = 0.1
    kalman = KalmanFilter(dt, u_x, u_y, std_acc, x_sdt_meas, y_sdt_meas)
    return kalman

# %%
def compute_iou(boxA, boxB):
    # Determine the coordinates of the intersection rectangle
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])

    # Compute the area of intersection rectangle
    interArea = max(0, xB - xA) * max(0, yB - yA)

    # Compute the area of both the prediction and ground-truth rectangles
    boxAArea = (boxA[2] - boxA[0]) * (boxA[3] - boxA[1])
    boxBArea = (boxB[2] - boxB[0]) * (boxB[3] - boxB[1])

    iou = interArea / float(boxAArea + boxBArea - interArea)

    return iou

# Convert the bounding box from [left, top, width, height] to [x1, y1, x2, y2]
df['x1'] = df['bb_left']
df['y1'] = df['bb_top']
df['x2'] = df['bb_left'] + df['bb_width']
df['y2'] = df['bb_top'] + df['bb_height']

# %%
df_frame1 = df[df['frame'] == 1]
df_frame2 = df[df['frame'] == 2]

def compute_iou_matrix(df_frame1, df_frame2):
    # Initialize an empty matrix for IoU between frame 1 and frame 2
    iou_matrix_frame1_frame2 = pd.DataFrame(np.zeros((len(df_frame1), len(df_frame2))), index=df_frame1.index,
                                            columns=df_frame2.index)
    # Compute IoU for each pair of bounding boxes between frame 1 and frame 2
    for i in df_frame1.index:
        boxA = df_frame1.loc[i, ['x1', 'y1', 'x2', 'y2']]
        for j in df_frame2.index:
            boxB = df_frame2.loc[j, ['x1', 'y1', 'x2', 'y2']]
            iou_matrix_frame1_frame2.at[i, j] = compute_iou(boxA, boxB)
    return iou_matrix_frame1_frame2

iou_matrix_frame1_frame2 = compute_iou_matrix(df_frame1, df_frame2)
# display the IoU matrix
print(iou_matrix_frame1_frame2)
# Out:
#          5         6         7         8         9    10
# 0  1.000000  0.000000  0.361845  0.000000  0.000000  0.0
# 1  0.000000  0.744732  0.000000  0.021989  0.000000  0.0
# 2  0.000000  0.000000  0.000000  0.544377  0.000000  0.0
# 3  0.000000  0.000000  0.000000  0.000000  0.633519  0.0
# 4  0.124487  0.000000  0.358332  0.000000  0.000000  0.0

# %%
def compute_embedings(boxes, img, model):
    embedings = []
    # get the sub part of the image for each box
    for i in boxes.index:
        box = boxes.loc[i, ['x1', 'y1', 'x2', 'y2']]
        box = box.astype(int)

        # check if the box is valid
        if box[0] < 0:
            box[0] = 0
        if box[1] < 0:
            box[1] = 0
        if box[2] > img.shape[1]:
            box[2] = img.shape[1]
        if box[3] > img.shape[0]:
            box[3] = img.shape[0]
        patch = img[box[1]:box[3], box[0]:box[2]]

        # resize the patch to 224x224
        patch = cv2.resize(patch, (224, 224))

        # convert to RGB
        patch = cv2.cvtColor(patch, cv2.COLOR_BGR2RGB)

        # convert to float
        patch = patch.astype(float)

        # normalize the patch
        patch /= 255.0

        # use the pre-trained model to extract the features
        patch = np.expand_dims(patch, axis=0)
        patch = model.predict(patch)
        patch = np.squeeze(patch)

        # append the features to the list of features
        embedings.append(patch)

    return embedings

model = tf.keras.applications.VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

image = cv2.imread('Filemail.com files 14.12.2023 fbhubejonusmcri/ADL-Rundle-6/img1/000001.jpg')
embedings = compute_embedings(df_frame1, image, model)

# display the shape of the features
print(embedings[0].shape)
print(len(embedings))
# Out:
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 77ms/step
# (7, 7, 512)
# 5

# %%
def dist_embedings(embeding1, embeding2):
    return np.linalg.norm(embeding1 - embeding2)

def compute_dist_matrix(df_frame1, df_frame2, image1, image2, model):
    # Initialize an empty matrix for distances between frame 1 and frame 2
    dist_matrix_frame1_frame2 = pd.DataFrame(np.zeros((len(df_frame1), len(df_frame2))), index=df_frame1.index,
                                             columns=df_frame2.index)

    embedings1 = compute_embedings(df_frame1, image1, model)
    embedings2 = compute_embedings(df_frame2, image2, model)
    # Compute distances for each pair of bounding boxes between frame 1 and frame 2
    for i in range(len(df_frame1)):
        for j in range(len(df_frame2)):
            i_index = df_frame1.index[i]
            j_index = df_frame2.index[j]
            dist_matrix_frame1_frame2.at[i_index, j_index] = dist_embedings(embedings1[i], embedings2[j])

    return dist_matrix_frame1_frame2
image1 = image
image2 = cv2.imread('Filemail.com files 14.12.2023 fbhubejonusmcri/ADL-Rundle-6/img1/000002.jpg')
dist_matrix_frame1_frame2 = compute_dist_matrix(df_frame1, df_frame2, image1, image2, model)
# display the distance matrix
print(dist_matrix_frame1_frame2)
# Out:
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 70ms/step
#           5          6          7          8          9          10
# 0  19.629091  47.639347  48.857929  49.181980  47.904743  48.657475
# 1  48.432415  26.519157  47.623394  41.012535  41.698673  38.607536
# 2  48.445724  36.737003  42.625557  30.035177  38.289688  27.420506
# 3  48.781109  41.501282  45.493465  42.514759  31.318941  39.351791
# 4  48.570000  40.235073  42.962437  43.540619  42.428474  39.535049

# %%
def is_similar_size_and_shape(boxA, boxB, size_threshold=0.5, ratio_threshold=0.5):
    # Calculate areas and aspect ratios
    areaA = (boxA[2] - boxA[0]) * (boxA[3] - boxA[1])
    areaB = (boxB[2] - boxB[0]) * (boxB[3] - boxB[1])
    ratioA = (boxA[2] - boxA[0]) / float(boxA[3] - boxA[1])
    ratioB = (boxB[2] - boxB[0]) / float(boxB[3] - boxB[1])

    # Compare areas and aspect ratios
    area_similar = min(areaA, areaB) / float(max(areaA, areaB)) > size_threshold
    ratio_similar = min(ratioA, ratioB) / float(max(ratioA, ratioB)) > ratio_threshold

    return area_similar and ratio_similar

# %%
sigma = 0.5

def associate_detections_to_tracks(iou_matrix, embeddings_matrix, df_frame1, df_frame2, sigma=0.5, alpha=0.6, beta=0.4):
    # Check shapes
    if iou_matrix.shape != embeddings_matrix.shape:
        print('iou_matrix and embeddings_matrix must have the same shape', iou_matrix.shape, embeddings_matrix.shape)
        return {}

    # Normalize IoU and embedding distances to a similar scale
    max_iou = max(iou_matrix.max().max(), 1) # Ensure no division by zero
    max_dist = max(embeddings_matrix.max().max(), 1)

    normalized_iou_matrix = iou_matrix / max_iou
    normalized_embeddings_matrix = 1 - (embeddings_matrix / max_dist) # Inverting the embeddings score

    # Create a combined score matrix
    combined_score_matrix = alpha * normalized_iou_matrix + beta * normalized_embeddings_matrix

    # Use Hungarian algorithm on the combined score matrix
    row_ind, col_ind = linear_sum_assignment(-combined_score_matrix.values)
    associations = {}

    for i in range(len(row_ind)):
        row = row_ind[i]
        col = col_ind[i]

        boxA = df_frame1.loc[combined_score_matrix.index[row], ['x1', 'y1', 'x2', 'y2']]
        boxB = df_frame2.loc[combined_score_matrix.columns[col], ['x1', 'y1', 'x2', 'y2']]

        # Check if boxes have similar size and shape
        if is_similar_size_and_shape(boxA, boxB) and combined_score_matrix.iloc[row, col] > sigma:
            associations[combined_score_matrix.index[row]] = combined_score_matrix.columns[col]

    return associations



# Example usage
associations_frame1_frame2 = associate_detections_to_tracks(iou_matrix_frame1_frame2, dist_matrix_frame1_frame2, df_frame1, df_frame2, sigma=0.5, alpha=0.6, beta=0.4)
associations_frame1_frame2
# Out:
# {0: 5, 1: 6, 3: 9}

# %%
# Initialize lists for matches, unmatched detections, and unmatched tracks
matches = []
unmatched_detections = list(df_frame2.index)
unmatched_tracks = list(df_frame1.index)

# Populate the lists based on the associations
for track_idx, detection_idx in associations_frame1_frame2.items():
    if detection_idx in unmatched_detections:
        # Add to matches and remove from unmatched lists
        matches.append((track_idx, detection_idx))
        unmatched_detections.remove(detection_idx)
    unmatched_tracks.remove(track_idx)

# Matches, unmatched detections, and unmatched tracks after processing
matches, unmatched_detections, unmatched_tracks
# Out:
# ([(0, 5), (1, 6), (3, 9)], [7, 8, 10], [2, 4])

# %%
def track_management_with_unique_ids(df, frame_range, frames, sigma=0.5):
    results = {}
    current_ids = {}
    next_id = 0
    history = {}
    filters = {}

    for frame in range(frame_range[0], frame_range[1]):
        print("======================================================================= frame ", frame, "=======================================================================")
        image1 = frames[frame - 1]
        image2 = frames[frame]

        #print('image1', image1.shape)
        #print('image2', image2.shape)
 
        df_current_frame = df[df['frame'] == frame]
        df_next_frame = df[df['frame'] == frame + 1]

        if df_current_frame.empty or df_next_frame.empty:
            continue

        iou_matrix = compute_iou_matrix(df_current_frame, df_next_frame)
        iou_matrix = iou_matrix.apply(pd.to_numeric)

        dist_matrix = compute_dist_matrix(df_current_frame, df_next_frame, image1, image2, model)
        dist_matrix = dist_matrix.apply(pd.to_numeric)

        associations = associate_detections_to_tracks(iou_matrix, dist_matrix, df_current_frame, df_next_frame, sigma=sigma)
        matches = []
        unmatched_detections = list(df_next_frame.index)
        unmatched_tracks = list(df_current_frame.index)

        for track_idx, detection_idx in associations.items():
            if detection_idx in unmatched_detections:
                track_id = current_ids.get(track_idx, next_id)
                if track_id not in filters:
                    filters[track_id] = create_kalman()  # Initialize a Kalman filter for the new track ID
                    next_id += 1

                current_ids[detection_idx] = track_id
                matches.append((track_id, detection_idx))
                unmatched_detections.remove(detection_idx)

                # Update Kalman filter for existing tracks
                if track_id in filters:
                    kalman = filters[track_id]
                    # Update kalman filter with current data
                    bb_left = df.loc[track_id, 'bb_left']
                    bb_top = df.loc[track_id, 'bb_top']
                    kalman.update([[bb_left], [bb_top]])
                    prediction = kalman.predict()
                    df.loc[track_id, 'bb_left'] = prediction[0]
                    df.loc[track_id, 'bb_top'] = prediction[1]
                    #update x1, y1, x2, y2
                    df.loc[track_id, 'x1'] = prediction[0]
                    df.loc[track_id, 'y1'] = prediction[1]
                    df.loc[track_id, 'x2'] = prediction[0] + df.loc[track_id, 'bb_width']
                    df.loc[track_id, 'y2'] = prediction[1] + df.loc[track_id, 'bb_height']
                    #print('update', track_id, 'former', bb_left, bb_top, 'new', prediction[0], prediction[1])


        for detection_idx in unmatched_detections:
            current_ids[detection_idx] = next_id
            filters[next_id] = create_kalman()  # Initialize a Kalman filter for the new detection
            next_id += 1

        for track_idx in unmatched_tracks:
            if track_idx in current_ids:
                del current_ids[track_idx]
            if track_idx in filters:
                del filters[track_idx]

        results[frame] = {
            'matches': matches,
            'unmatched_detections': unmatched_detections,
            'unmatched_tracks': unmatched_tracks
        }
        #print('results', results[frame])
        #print('filters', filters.keys())

        for track_idx, detection_idx in matches:
            if track_idx in history:
                history[track_idx].append(detection_idx)
            else:
                history[track_idx] = [detection_idx]

    return results, next_id, history

# Apply the modified track management to our data
frame_range = (1, 12)
frames = []
for frame in range(frame_range[0], frame_range[1] + 1):
    image = cv2.imread('Filemail.com files 14.12.2023 fbhubejonusmcri/ADL-Rundle-6/img1/{:06d}.jpg'.format(frame))
    frames.append(image)
track_management_results, _, history = track_management_with_unique_ids(df, frame_range, frames, sigma=0.5)
print(track_management_results)
print(history)
# Out:
# ======================================================================= frame  1 =======================================================================
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# ======================================================================= frame  2 =======================================================================
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 78ms/step
# ======================================================================= frame  3 =======================================================================
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 81ms/step
# ======================================================================= frame  4 =======================================================================
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 71ms/step
# ======================================================================= frame  5 =======================================================================
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# ======================================================================= frame  6 =======================================================================
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 83ms/step
# ======================================================================= frame  7 =======================================================================
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  8 =======================================================================
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# ======================================================================= frame  9 =======================================================================
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 71ms/step
# ======================================================================= frame  10 =======================================================================
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  11 =======================================================================
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# {1: {'matches': [(0, 5), (1, 6), (2, 9)], 'unmatched_detections': [7, 8, 10], 'unmatched_tracks': [0, 1, 2, 3, 4]}, 2: {'matches': [(1, 13), (2, 17)], 'unmatched_detections': [11, 12, 14, 15, 16], 'unmatched_tracks': [5, 6, 7, 8, 9, 10]}, 3: {'matches': [(9, 18), (1, 21), (10, 19), (12, 22), (2, 23)], 'unmatched_detections': [20], 'unmatched_tracks': [11, 12, 13, 14, 15, 16, 17]}, 4: {'matches': [(15, 25)], 'unmatched_detections': [24, 26, 27], 'unmatched_tracks': [18, 19, 20, 21, 22, 23]}, 5: {'matches': [(15, 29), (18, 31), (19, 28)], 'unmatched_detections': [30, 32, 33], 'unmatched_tracks': [24, 25, 26, 27]}, 6: {'matches': [(19, 34), (15, 35)], 'unmatched_detections': [36, 37, 38, 39], 'unmatched_tracks': [28, 29, 30, 31, 32, 33]}, 7: {'matches': [(19, 40), (15, 42), (25, 41)], 'unmatched_detections': [43, 44], 'unmatched_tracks': [34, 35, 36, 37, 38, 39]}, 8: {'matches': [(19, 45), (25, 46), (15, 47), (30, 51)], 'unmatched_detections': [48, 49, 50], 'unmatched_tracks': [40, 41, 42, 43, 44]}, 9: {'matches': [(19, 52), (25, 53), (15, 57), (32, 54), (33, 56), (30, 55)], 'unmatched_detections': [], 'unmatched_tracks': [45, 46, 47, 48, 49, 50, 51]}, 10: {'matches': [(19, 58), (25, 59), (30, 60), (33, 61)], 'unmatched_detections': [62, 63], 'unmatched_tracks': [52, 53, 54, 55, 56, 57]}, 11: {'matches': [(19, 64), (25, 65), (35, 67)], 'unmatched_detections': [66, 68], 'unmatched_tracks': [58, 59, 60, 61, 62, 63]}}
# {0: [5], 1: [6, 13, 21], 2: [9, 17, 23], 9: [18], 10: [19], 12: [22], 15: [25, 29, 35, 42, 47, 57], 18: [31], 19: [28, 34, 40, 45, 52, 58, 64], 25: [41, 46, 53, 59, 65], 30: [51, 55, 60], 32: [54], 33: [56, 61], 35: [67]}

# %%
# Function to draw bounding boxes, IDs, and trajectories
def draw_tracking_info(df, image, matches, unmatched_detections, unmatched_tracks, history):
    # Define colors
    color_matched = (0, 255, 0)  # Green for matched
    color_unmatched_detection = (0, 0, 255)  # Red for unmatched detection
    color_unmatched_track = (255, 0, 0)  # Blue for unmatched track
    color_line = (0, 255, 255)  # Yellow for trajectory line
    
    # Draw matched tracks and their trajectories
    for track_idx, detection_idx in matches:
        # Get the bounding box of the detection
        bb_left = int(df.loc[detection_idx, 'bb_left'])
        bb_top = int(df.loc[detection_idx, 'bb_top'])
        bb_width = int(df.loc[detection_idx, 'bb_width'])
        bb_height = int(df.loc[detection_idx, 'bb_height'])
        
        # Draw the bounding box
        cv2.rectangle(image, (bb_left, bb_top), (bb_left + bb_width, bb_top + bb_height), color_matched, 2)
        
        # Annotate the bounding box with the track ID
        cv2.putText(image, str(track_idx), (bb_left, bb_top - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color_matched, 2)
        
        # get the track ID
        #track_id = int(df.loc[track_idx, 'id'])
        
        
        # Annotate the image with the track ID
        #cv2.putText(image, 'Track ' + str(track_id), (cx + 5, cy + 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color_matched, 2)
        
        #print(track_idx)
        # Draw the trajectory line
        if track_idx in history:
            #print(history[track_idx])
            cx = None
            cy = None
            for detection_idx_2 in history[track_idx]:
                if cx is None:
                    # Get the centroid of the detection
                    cx = int(df.loc[detection_idx_2, 'bb_left']) + int(df.loc[detection_idx_2, 'bb_width']) // 2
                    cy = int(df.loc[detection_idx_2, 'bb_top']) + int(df.loc[detection_idx_2, 'bb_height']) // 2
                    #print(cx, cy)
                    # Draw the centroid
                    cv2.circle(image, (cx, cy), 2, color_line, 2)
                    if detection_idx_2 == detection_idx:
                        break
                    continue
                #print(detection_idx_2)
                # Get the centroid of the detection
                cx_2 = int(df.loc[detection_idx_2, 'bb_left']) + int(df.loc[detection_idx_2, 'bb_width']) // 2
                cy_2 = int(df.loc[detection_idx_2, 'bb_top']) + int(df.loc[detection_idx_2, 'bb_height']) // 2

                #print(cx, cy, cx_2, cy_2)
                
                # Draw the centroid
                cv2.circle(image, (cx_2, cy_2), 2, color_line, 2)
                
                # Draw the line
                cv2.line(image, (cx, cy), (cx_2, cy_2), color_line, 2)
                
                # Update the centroid
                cx = cx_2
                cy = cy_2

                if detection_idx_2 == detection_idx:
                    break
    
    # Draw unmatched detections
    for detection_idx in unmatched_detections:
        # Get the bounding box of the detection
        bb_left = int(df.loc[detection_idx, 'bb_left'])
        bb_top = int(df.loc[detection_idx, 'bb_top'])
        bb_width = int(df.loc[detection_idx, 'bb_width'])
        bb_height = int(df.loc[detection_idx, 'bb_height'])
        
        # Draw the bounding box
        cv2.rectangle(image, (bb_left, bb_top), (bb_left + bb_width, bb_top + bb_height), color_unmatched_detection, 2)
        
        # Annotate the bounding box with the detection ID
        cv2.putText(image, 'Detection ' + str(detection_idx), (bb_left, bb_top - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color_unmatched_detection, 2)

    return image

# Load the first frame of the video
image = cv2.imread('Filemail.com files 14.12.2023 fbhubejonusmcri/ADL-Rundle-6/img1/000001.jpg')
height, width, channels = image.shape

# Draw the tracking info on the image
image = draw_tracking_info(df, image, track_management_results[1]['matches'], 
        track_management_results[1]['unmatched_detections'], 
        track_management_results[1]['unmatched_tracks'],
        history)
print(history)

# Display the image
plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# {0: [5], 1: [6, 13, 21], 2: [9, 17, 23], 9: [18], 10: [19], 12: [22], 15: [25, 29, 35, 42, 47, 57], 18: [31], 19: [28, 34, 40, 45, 52, 58, 64], 25: [41, 46, 53, 59, 65], 30: [51, 55, 60], 32: [54], 33: [56, 61], 35: [67]}

# %%
# do it on the whole video and display it in time frame by frame with cv2.imshow
frame_range = (1, 525)

# Load all the frames of the video
frames = []
for frame in range(frame_range[0], frame_range[1] + 1):
    image = cv2.imread('Filemail.com files 14.12.2023 fbhubejonusmcri/ADL-Rundle-6/img1/{:06d}.jpg'.format(frame))
    frames.append(image)

# computes the tracks on the whole video
track_management_results_updated, ids, history = track_management_with_unique_ids(df, frame_range, frames)
print(track_management_results_updated)
print(history)
# Out:
# ======================================================================= frame  1 =======================================================================
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  2 =======================================================================
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  3 =======================================================================
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# ======================================================================= frame  4 =======================================================================
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  5 =======================================================================
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  6 =======================================================================
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# ======================================================================= frame  7 =======================================================================
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# ======================================================================= frame  8 =======================================================================
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  9 =======================================================================
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  10 =======================================================================
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  11 =======================================================================
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# ======================================================================= frame  12 =======================================================================
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  13 =======================================================================
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  14 =======================================================================
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  15 =======================================================================
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  16 =======================================================================
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 72ms/step
# ======================================================================= frame  17 =======================================================================
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 73ms/step
# ======================================================================= frame  18 =======================================================================
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# ======================================================================= frame  19 =======================================================================
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# ======================================================================= frame  20 =======================================================================
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  21 =======================================================================
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  22 =======================================================================
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# ======================================================================= frame  23 =======================================================================
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  24 =======================================================================
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# ======================================================================= frame  25 =======================================================================
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  26 =======================================================================
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  27 =======================================================================
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  28 =======================================================================
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# ======================================================================= frame  29 =======================================================================
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  30 =======================================================================
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# ======================================================================= frame  31 =======================================================================
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# ======================================================================= frame  32 =======================================================================
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  33 =======================================================================
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  34 =======================================================================
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# ======================================================================= frame  35 =======================================================================
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 71ms/step
# ======================================================================= frame  36 =======================================================================
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  37 =======================================================================
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  38 =======================================================================
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# ======================================================================= frame  39 =======================================================================
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# ======================================================================= frame  40 =======================================================================
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# ======================================================================= frame  41 =======================================================================
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  42 =======================================================================
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# ======================================================================= frame  43 =======================================================================
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# ======================================================================= frame  44 =======================================================================
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  45 =======================================================================
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# ======================================================================= frame  46 =======================================================================
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 72ms/step
# ======================================================================= frame  47 =======================================================================
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# ======================================================================= frame  48 =======================================================================
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 71ms/step
# ======================================================================= frame  49 =======================================================================
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 70ms/step
# ======================================================================= frame  50 =======================================================================
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# ======================================================================= frame  51 =======================================================================
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 73ms/step
# ======================================================================= frame  52 =======================================================================
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  53 =======================================================================
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  54 =======================================================================
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  55 =======================================================================
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  56 =======================================================================
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# ======================================================================= frame  57 =======================================================================
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# ======================================================================= frame  58 =======================================================================
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# ======================================================================= frame  59 =======================================================================
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# ======================================================================= frame  60 =======================================================================
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 69ms/step
# ...
# 1/1 [==============================] - 0s 74ms/step
# ======================================================================= frame  518 =======================================================================
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 83ms/step
# ======================================================================= frame  519 =======================================================================
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 89ms/step
# ======================================================================= frame  520 =======================================================================
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 73ms/step
# ======================================================================= frame  521 =======================================================================
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 72ms/step
# ======================================================================= frame  522 =======================================================================
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 86ms/step
# ======================================================================= frame  523 =======================================================================
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 73ms/step
# ======================================================================= frame  524 =======================================================================
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 72ms/step
# {1: {'matches': [(0, 5), (1, 9)], 'unmatched_detections': [6, 7, 8, 10], 'unmatched_tracks': [0, 1, 2, 3, 4]}, 2: {'matches': [(2, 13), (1, 17)], 'unmatched_detections': [11, 12, 14, 15, 16], 'unmatched_tracks': [5, 6, 7, 8, 9, 10]}, 3: {'matches': [(8, 19), (9, 18), (2, 21), (12, 22), (1, 23)], 'unmatched_detections': [20], 'unmatched_tracks': [11, 12, 13, 14, 15, 16, 17]}, 4: {'matches': [(9, 27)], 'unmatched_detections': [24, 25, 26], 'unmatched_tracks': [18, 19, 20, 21, 22, 23]}, 5: {'matches': [(18, 31), (9, 28)], 'unmatched_detections': [29, 30, 32, 33], 'unmatched_tracks': [24, 25, 26, 27]}, 6: {'matches': [(9, 34), (21, 36)], 'unmatched_detections': [35, 37, 38, 39], 'unmatched_tracks': [28, 29, 30, 31, 32, 33]}, 7: {'matches': [(9, 40), (21, 41)], 'unmatched_detections': [42, 43, 44], 'unmatched_tracks': [34, 35, 36, 37, 38, 39]}, 8: {'matches': [(9, 45), (21, 46), (28, 47), (30, 51)], 'unmatched_detections': [48, 49, 50], 'unmatched_tracks': [40, 41, 42, 43, 44]}, 9: {'matches': [(9, 52), (21, 53), (28, 57), (32, 54), (33, 56), (30, 55)], 'unmatched_detections': [], 'unmatched_tracks': [45, 46, 47, 48, 49, 50, 51]}, 10: {'matches': [(9, 58), (21, 59), (30, 60), (33, 61)], 'unmatched_detections': [62, 63], 'unmatched_tracks': [52, 53, 54, 55, 56, 57]}, 11: {'matches': [(9, 64), (21, 65), (35, 67)], 'unmatched_detections': [66, 68], 'unmatched_tracks': [58, 59, 60, 61, 62, 63]}, 12: {'matches': [(9, 69), (21, 70), (37, 71)], 'unmatched_detections': [72, 73, 74], 'unmatched_tracks': [64, 65, 66, 67, 68]}, 13: {'matches': [(9, 75), (21, 76), (37, 79), (40, 80)], 'unmatched_detections': [77, 78], 'unmatched_tracks': [69, 70, 71, 72, 73, 74]}, 14: {'matches': [(9, 81), (21, 83), (42, 84), (37, 85), (40, 86)], 'unmatched_detections': [82], 'unmatched_tracks': [75, 76, 77, 78, 79, 80]}, 15: {'matches': [(9, 87), (43, 88), (21, 89), (42, 90), (37, 91)], 'unmatched_detections': [92], 'unmatched_tracks': [81, 82, 83, 84, 85, 86]}, 16: {'matches': [(9, 93), (21, 94), (42, 96)], 'unmatched_detections': [95], 'unmatched_tracks': [87, 88, 89, 90, 91, 92]}, 17: {'matches': [(9, 97), (21, 99), (42, 98)], 'unmatched_detections': [100, 101, 102], 'unmatched_tracks': [93, 94, 95, 96]}, 18: {'matches': [(9, 103), (42, 104), (21, 105), (46, 106), (47, 107), (48, 108)], 'unmatched_detections': [], 'unmatched_tracks': [97, 98, 99, 100, 101, 102]}, 19: {'matches': [(9, 109), (42, 110), (21, 112), (46, 111), (47, 114), (48, 113)], 'unmatched_detections': [], 'unmatched_tracks': [103, 104, 105, 106, 107, 108]}, 20: {'matches': [(9, 115), (42, 116), (46, 118), (21, 117), (48, 120)], 'unmatched_detections': [119], 'unmatched_tracks': [109, 110, 111, 112, 113, 114]}, 21: {'matches': [(9, 121), (42, 122), (21, 123), (46, 124), (48, 126)], 'unmatched_detections': [125, 127], 'unmatched_tracks': [115, 116, 117, 118, 119, 120]}, 22: {'matches': [(9, 128), (42, 129), (21, 130), (46, 131), (50, 132), (48, 133)], 'unmatched_detections': [], 'unmatched_tracks': [121, 122, 123, 124, 125, 126, 127]}, 23: {'matches': [(9, 137), (42, 135), (21, 136), (46, 134), (50, 139), (48, 138)], 'unmatched_detections': [], 'unmatched_tracks': [128, 129, 130, 131, 132, 133]}, 24: {'matches': [(46, 140), (42, 142), (21, 141), (9, 143), (48, 145)], 'unmatched_detections': [144, 146, 147], 'unmatched_tracks': [134, 135, 136, 137, 138, 139]}, 25: {'matches': [(46, 148), (21, 149), (42, 153), (9, 152), (48, 151), (54, 155)], 'unmatched_detections': [150, 154, 156], 'unmatched_tracks': [140, 141, 142, 143, 144, 145, 146, 147]}, 26: {'matches': [(46, 157), (21, 158), (55, 159), (48, 160), (9, 161), (54, 162)], 'unmatched_detections': [163, 164], 'unmatched_tracks': [148, 149, 150, 151, 152, 153, 154, 155, 156]}, 27: {'matches': [(46, 165), (21, 166), (48, 169), (54, 168)], 'unmatched_detections': [167, 170], 'unmatched_tracks': [157, 158, 159, 160, 161, 162, 163, 164]}, 28: {'matches': [(46, 171), (21, 172), (60, 173), (48, 177)], 'unmatched_detections': [174, 175, 176], 'unmat ...
# {0: [5], 1: [9, 17, 23], 2: [13, 21], 8: [19], 9: [18, 27, 28, 34, 40, 45, 52, 58, 64, 69, 75, 81, 87, 93, 97, 103, 109, 115, 121, 128, 137, 143, 152, 161], 12: [22], 18: [31], 21: [36, 41, 46, 53, 59, 65, 70, 76, 83, 89, 94, 99, 105, 112, 117, 123, 130, 136, 141, 149, 158, 166, 172, 179, 187, 195, 201, 207, 213, 219, 225, 231, 238, 243, 248, 253, 259, 264, 269, 274, 280, 289, 295, 302, 308, 313, 318, 324, 331, 339, 346, 351, 361, 368, 376, 386, 395, 403, 410, 418, 426, 435, 443, 451, 463, 475, 487, 495, 504, 518, 527, 536, 546, 558, 566, 575, 580, 590, 600, 609, 619, 628, 636, 650, 660, 669], 28: [47, 57], 30: [51, 55, 60], 32: [54], 33: [56, 61], 35: [67], 37: [71, 79, 85, 91], 40: [80, 86], 42: [84, 90, 96, 98, 104, 110, 116, 122, 129, 135, 142, 153], 43: [88], 46: [106, 111, 118, 124, 131, 134, 140, 148, 157, 165, 171, 178, 186, 194, 200, 206, 212, 218, 224, 230, 237, 242, 247, 252, 258, 263, 268], 47: [107, 114], 48: [108, 113, 120, 126, 133, 138, 145, 151, 160, 169, 177], 50: [132, 139], 54: [155, 162, 168], 55: [159], 60: [173, 181, 190], 62: [183, 191], 65: [188], 68: [192], 69: [198, 204, 209, 216, 222], 71: [202, 208, 215, 221, 227, 233, 239, 244, 249, 254, 260, 265, 270, 275, 281, 290, 296, 303, 310, 314, 319, 325, 333, 340, 348, 352, 360, 367, 375, 384, 394, 402, 411, 419, 425, 434, 442, 450, 464, 477, 488, 497, 507, 519, 528, 537, 548, 559, 568, 576, 581], 72: [205, 210, 214, 220, 226, 232], 74: [211], 79: [240], 81: [241], 82: [250], 83: [251], 92: [278], 93: [279, 288, 294, 301, 307, 312, 317, 323], 94: [283, 291, 297, 304, 309, 315, 321, 326], 95: [285], 97: [292, 299], 100: [298, 306], 104: [320], 106: [337], 107: [336], 108: [335, 342, 350, 355, 365], 109: [338, 345, 353, 362, 370, 377, 387, 397, 405, 414, 422, 429, 439], 110: [343, 349], 111: [341, 347, 354], 113: [363, 369], 119: [382, 388, 398, 406], 120: [383, 390], 121: [378, 389, 396, 404, 412, 421, 428, 437, 445, 453, 466, 480, 491, 499, 510, 521, 531, 541, 550, 560, 570, 577, 586, 595, 605, 614, 624, 635, 643, 653, 663, 671, 679, 687, 697, 704, 710, 718, 725, 734, 741, 747, 755, 762, 769, 775, 782, 792, 798, 805, 810, 818, 825, 831, 836, 842, 849, 854, 861, 867, 875, 886, 894, 904, 913, 924, 934, 942, 953, 962, 965, 973, 981, 988, 994, 1002, 1011, 1020, 1028, 1038, 1050, 1058, 1067, 1074, 1080, 1089, 1099, 1109, 1118, 1128, 1138, 1150, 1162, 1173, 1179, 1186, 1193, 1206, 1215, 1221, 1232, 1248], 122: [385], 126: [400], 128: [401], 129: [407, 415, 423, 431], 132: [420], 134: [427, 436, 444, 452, 462, 476, 486, 496, 505, 517, 529, 538, 547, 557, 567, 574, 582, 591, 599, 608, 618, 630, 639, 651], 135: [430], 140: [449, 461, 473, 483], 142: [456, 465], 143: [459], 147: [471], 151: [478, 489, 500], 152: [484, 493], 153: [485, 492], 156: [490, 501], 158: [503, 514, 526], 159: [506], 160: [511, 523], 163: [522], 165: [525, 533], 168: [532, 542, 549, 561, 569, 578, 585, 596, 604, 611, 622, 632, 641, 652, 662, 670, 680, 689, 699, 706, 714], 169: [540, 553], 171: [545], 172: [551, 564], 174: [554, 565, 572], 175: [563], 177: [562], 180: [583, 594, 603, 613, 625, 633, 646, 655], 184: [598, 602, 612, 621, 629, 637, 649, 658, 667, 678, 686, 696, 705, 712, 720], 185: [601, 610, 620, 627, 638], 186: [606, 615, 623, 631, 647], 188: [617], 191: [644, 654, 664], 193: [656, 665, 675], 194: [657, 666, 673, 683, 691], 195: [659, 668], 197: [677], 200: [685, 695, 702, 709, 717, 723, 732, 740, 746], 202: [690, 700], 203: [698], 205: [701], 207: [711, 719, 726, 735, 742, 748, 756, 763, 771, 777], 209: [715], 212: [729], 213: [730], 214: [733], 215: [736, 744, 750, 758, 764, 770, 776, 786], 216: [739], 217: [737], 218: [745, 751, 759, 766, 773, 778, 785, 796], 219: [749], 222: [761, 768, 774, 781, 791, 797, 804, 809, 817, 824, 832, 835, 843, 848, 853, 860, 866, 877, 884, 895, 903, 914, 925, 936, 944, 952], 223: [765, 772, 779, 787, 795, 801, 808, 815, 823, 829], 226: [788], 231: [800, 806], 232: [799], 235: [812, 820, 827], 237: [822, 830], 238: [821], 241: [833, 837, 841, 84 ...

# %%
# imshow for each frame
for frame in range(frame_range[0], frame_range[1]):
    # Load the frame
    image = frames[frame - frame_range[0]]

    # Draw the tracking info on the image
    image = draw_tracking_info(df, image, track_management_results_updated[frame]['matches'], 
        track_management_results_updated[frame]['unmatched_detections'], 
        track_management_results_updated[frame]['unmatched_tracks'],
        history)
    # Display the image
    cv2.imshow('Frame', image)
    cv2.waitKey(20)

cv2.destroyAllWindows()

# %%
#print nb of obj at the end of the video
print(ids)
# Out:
# 1462

# %%
# save as in gt.txt
# save in a txt file
# format : frame, id, bb_left, bb_top, bb_width, bb_height, conf, x, y, z
# Replace the 'id' column in df with the computed IDs, using history
new_df = df.copy()
new_df['id'] = -1  # Initialize all IDs to -1
for track_idx, detection_idx_list in history.items():
    new_df.at[track_idx, 'id'] = track_idx  # Assign the track ID to the detection
    for detection_idx in detection_idx_list:
        new_df.at[detection_idx, 'id'] = track_idx

# remove the columns that are not needed
new_df = new_df.drop(columns=['x1', 'y1', 'x2', 'y2'])

# remove unwanted rows
new_df = new_df[new_df['id'] != -1]

# Save the modified DataFrame as 'predict.txt'
new_df.to_csv('predict.txt', sep=',', index=False, header=False)
